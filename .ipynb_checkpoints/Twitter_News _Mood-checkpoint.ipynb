# %% [markdown]
# # Analysis
#
# 1. CNN and Fox News had the most negative Vader sentiment analysis.
# 2. The New York Times had a slightly negative score of -0.02. Even though its score is slightly negative, the New York Times had the scores closes to zero. It is the news outlet with the closest to neutral sentiment.
# 3. While both the BBC and CBS had an overall positive Vader scores CBS had the highest score with 0.2. the BBC had 0.09.
# 4. The validity of the Vader analysis is questionable. There are tweets of negative events that have neutral Vader scores instead of expected negative Vader scores.
# 5. The Vader analysis on news organizations is highly dependent on the type of news happens on a particular day. A more fair analysis would analyze a larger sample of tweets over a larger period of time.

# %%
#Dependencies.

import tweepy
import json
import pandas as pd
import numpy as np
import time
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 # Import and Initialize Sentiment Analyzer.
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#Twitter API keys

consumer_key = "4JPyi4nFzwCJTxf2M6WzKj1xe"
consumer_secret = "JK62tMorfWHYRTQyJggN6JJSra4MHag6h7QLolvWtMVrZ1h0cy"
access_token = "27365820-SLlpBaUtl0ITSCZe9Tdm6nCzpe3Quc4ZPsKyjyDUV"
access_token_secret = "L54XxUoSjFnLsXd0zDHfG57ziW2hE5PmdOm0OLmA3D47z"

# %%
# Setup Tweepy API Authentication.

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#Get tweets from each news organization's twitter feeds.



# A list to hold sentiments.

sentiments = []

target_users = ("@BBC", "@CBS", "@CNN", "@FoxNews", "@NYTimes")

#Loop though target users.

for user in target_users:
    
    #Counter 

    counter = 0
    
    #Loop through 5 pages of tweets for each news organization.


    #Get all tweets from the homefeed of each news organization.

    public_tweets = api.user_timeline(user, count = 100)

        #Loop through all tweets.

    for tweet in public_tweets:

        #Run the Vader analysis on each tweet.

        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        tweet_text = tweet["text"]

        #Add sentiments for each tweet to the sentiments list.

        sentiments.append({"User" : user,
                           "Date": tweet["created_at"],
                           "Compound" : compound,
                           "Positive" : pos,
                           "Negative" : neg,
                           "Neutral" : neu,
                           "Tweets Ago" : counter,
                           "Tweet Text" : tweet_text})
        #Add to counter.

        counter = counter + 1

# %%
#Create DataFrame.

news_sentiments = pd.DataFrame.from_dict(sentiments)
news_sentiments
# Out:
#      Compound                            Date  Negative  Neutral  Positive  \
# 0      0.0000  Thu Oct 04 20:06:04 +0000 2018     0.000    1.000     0.000
# 1     -0.5209  Thu Oct 04 19:01:08 +0000 2018     0.227    0.673     0.101
# 2      0.0000  Thu Oct 04 18:01:09 +0000 2018     0.000    1.000     0.000
# 3     -0.6124  Thu Oct 04 17:11:06 +0000 2018     0.260    0.640     0.100
# 4      0.4215  Thu Oct 04 16:03:07 +0000 2018     0.000    0.714     0.286
# 5     -0.4588  Thu Oct 04 15:29:47 +0000 2018     0.242    0.670     0.088
# 6      0.0000  Thu Oct 04 14:01:23 +0000 2018     0.000    1.000     0.000
# 7      0.1531  Thu Oct 04 13:03:03 +0000 2018     0.000    0.849     0.151
# 8     -0.2500  Thu Oct 04 12:02:05 +0000 2018     0.357    0.429     0.214
# 9      0.4404  Thu Oct 04 11:28:10 +0000 2018     0.000    0.813     0.187
# 10     0.0000  Thu Oct 04 11:13:01 +0000 2018     0.000    1.000     0.000
# 11     0.1759  Thu Oct 04 10:45:47 +0000 2018     0.206    0.546     0.248
# 12     0.0000  Thu Oct 04 10:26:38 +0000 2018     0.000    1.000     0.000
# 489    0.1354  Thu Oct 04 13:14:43 +0000 2018     0.085    0.806     0.109
# 490    0.0772  Thu Oct 04 13:11:03 +0000 2018     0.000    0.929     0.071
# 491    0.0000  Thu Oct 04 13:00:09 +0000 2018     0.000    1.000     0.000
# 492    0.0000  Thu Oct 04 12:44:02 +0000 2018     0.000    1.000     0.000
# 493   -0.3818  Thu Oct 04 12:30:04 +0000 2018     0.167    0.732     0.102
# 494    0.3612  Thu Oct 04 12:15:06 +0000 2018     0.000    0.872     0.128
# 495   -0.5994  Thu Oct 04 12:05:04 +0000 2018     0.240    0.687     0.073
# 496    0.0000  Thu Oct 04 11:46:04 +0000 2018     0.000    1.000     0.000
# 497   -0.5106  Thu Oct 04 11:30:05 +0000 2018     0.171    0.829     0.000
# 498    0.0000  Thu Oct 04 11:15:06 +0000 2018     0.000    1.000     0.000
# 499    0.0000  Thu Oct 04 11:00:14 +0000 2018     0.000    1.000     0.000
#
#                                             Tweet Text  Tweets Ago      User
# 0    🎶 @BTS_twt is the #KPop band taking over the w...           0      @BBC
# 1    Could the power of fake pills be used to treat...           1      @BBC
# 2    This is how homophobia feels in 2018. \n#Natio...           2      @BBC
# 3    🥓 Regularly eating foods like bacon and sausag...           3      @BBC
# 4    Maya Angelou: prolific, powerful, and a polyma...           4      @BBC
# 5    RT @BBCWales: Forget the lies and the myths ab...           5      @BBC
# 6    How did Shakespeare invent all those clichés? ...           6      @BBC
# 7    🌡🌍 What does 1.5C mean in a warming world?\n👉 ...           7      @BBC
# 8      Are you feeling lonely? https://t.co/HxqBp6oh17           8      @BBC
# 9    RT @BBCEarth: This #WorldAnimalDay, we’re givi...           9      @BBC
# 10   Ever heard a beatboxing starling? 🔊🔊\n#WorldAn...          10      @BBC
# 11   The pika might just be the world's cutest thie...          11      @BBC
# 12   Could this squat be a moment that sparks chang...          12      @BBC
# 13   🐬 A dolphin with a prosthetic tail inspired El...          13      @BBC
# 14   🥗 Eating a Mediterranean diet may help prevent...          14      @BBC
# 15   3 homeless people die every week in the UK.\nM...          15      @BBC
# 16   The search for Lord Sugar's next business part...          16      @BBC
# 17   🎧❤️ Dementia playlists are making such a big d...          17      @BBC
# 18   RT @BBCnireland: ✍ @BBCApprentice is back toni...          18      @BBC
# 19   ❤️ Couples will soon be able to choose a civil...          19      @BBC
# 20   🍜 The humble origins of an incredibly versatil...          20      @BBC
# 21   🌙 'Leonardo da Vinci was the first recorded pe...          21      @BBC
# 22   That time @RyanGosling was training to be an a...          22      @BBC
# 23   🕺🎙 'Tom Daley was an Elvis impersonator - with...          23      @BBC
# 24   19-year-old rapper Kitch has a stutter when he...          24      @BBC
# 25   RT @BBCRadio2: 🥁Drumroll please!🥁\n\nOur brand...          25      @BBC
# 26   🐧 A zoo has been forced to fill its new pengui...          26      @BBC
# 27   "Oh, I'm so sorry," and other things not to sa...          27      @BBC
# 28   Discover the extraordinary story of how a smal...          28      @BBC
# 29   Knife crime is up 22%. Who are the victims and...          29      @BBC
# ..                                                 ...         ...       ...
# 470  See the full list of the MacArthur “Genius” Gr...          70  @NYTimes
# 471  Meet the new MacArthur “genius” grant winners....          71  @NYTimes
# 472  Breaking News: 2 undecided GOP senators sugges...          72  @NYTimes
# 473  NBC gave Michael Schur total freedom. So the T...          73  @NYTimes
# 474  Barnes &amp; Noble announced that is consideri...          74  @NYTimes
# 475  RT @panphil: “It’s difficult to explain what Q...          75  @NYTimes
# 476  As senators read FBI interview transcripts, th...          76  @NYTimes
# 477  RT @nytgraphics: A map of where China’s retali...          77  @NYTimes
# 478  By the Book: If you want a book to better unde...          78  @NYTimes
# 479  RT @ScottShaneNYT: 3/ And according to the est...          79  @NYTimes
# 480  RT @ScottShaneNYT: 2/ Turns out that on Decemb...          80  @NYTimes
# 481  RT @ScottShaneNYT: 1/ Here's a remarkable upda...          81  @NYTimes
# 482  Breaking News: Russian officers launched cyber...          82  @NYTimes
# 483  In a video, Emmanuel Macron was seen as lectur...          83  @NYTimes
# 484  RT @MarkLandler: Tensions with China are about...          84  @NYTimes
# 485  RT @mikiebarb: On today’s Daily: the meaning a...          85  @NYTimes
# 486  Jimmy Kimmel's show paused multiple times as a...          86  @NYTimes
# 487  "Too often, when 'alternative medicine' is use...          87  @NYTimes
# 488  The most famous faces of the ’90s returned to ...          88  @NYTimes
# 489  Trump has insisted that his father provided al...          89  @NYTimes
# 490  On Wednesday, some Senate Republicans were ste...          90  @NYTimes
# 491  Morning Briefing: Here's what you need to know...          91  @NYTimes
# 492  RT @stavernise: The last time half of eligible...          92  @NYTimes
# 493  A white mob rampaged through a wealthy black b...          93  @NYTimes
# 494  RT @hkbeech: In Petobo, the earth churned as i...          94  @NYTimes
# 495  Your daily @DealBook Briefing:\n\n• eBay accus...          95  @NYTimes
# 496  A small army of African-American women across ...          96  @NYTimes
# 497  "The president insulted our country, our prime...          97  @NYTimes
# 498  Our investigation revealed that Donald Trump r...          98  @NYTimes
# 499  The FBI's Kavanaugh investigation https://t.co...          99  @NYTimes
#
# [500 rows x 8 columns]

# %%
#Export the DataFrame to as csv.

news_sentiments.to_csv("Twitter_News_Mood.csv", index=False)

# %%
#Plot scatterplot graph.

# Set the x limit,
plt.xlim(101, -1)

#plot scatterplot using a for loop.
for user in target_users:
    dataframe = news_sentiments.loc[news_sentiments["User"] == user]
    plt.scatter(dataframe["Tweets Ago"],dataframe["Compound"],label = user)
    
#Add legend
plt.legend(bbox_to_anchor = (1,1))

#Add title, x axis label, and y axis label.
plt.title("Sentiment Analysis of Media Tweets (11/5/2017)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

#Set a grid on the plot.
plt.grid()

plt.savefig("Sentiment Analysis of Media Tweets")
plt.show()

# %%
average_sentiment = news_sentiments.groupby("User")["Compound"].mean()
average_sentiment
# Out:
# User
# @BBC        0.020374
# @CBS        0.155590
# @CNN        0.023314
# @FoxNews   -0.036073
# @NYTimes    0.065884
# Name: Compound, dtype: float64

# %%
x_axis = np.arange(len(average_sentiment))
xlabels = average_sentiment.index
count = 0
for sentiment in average_sentiment:
    plt.text(count, sentiment+.01, str(round(sentiment,2)))
    count = count + 1
plt.bar(x_axis, average_sentiment, tick_label = xlabels, color = ['silver', 'b', 'y', 'g', 'c'])
#Set title, x axis label, and y axis label.
plt.title("Overall Sentiment of Media Tweets (11/5/2017)")
plt.xlabel("New Organizations")
plt.ylabel("Tweet Polarity")
plt.savefig("Overall Sentiment of Media Tweets")
plt.show()
